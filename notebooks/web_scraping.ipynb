# %% [markdown]
# ## Smartphone Market Analysis & Price Prediction using Web Scraping – Flipkart Case Study
#
# ### Project Overview
#
# This project focuses on performing live web scraping from Flipkart to extract real-time smartphone data using Python libraries such as Requests and BeautifulSoup. The rapidly evolving smartphone market, characterized by frequent product launches and dynamic pricing, makes automated data collection essential for continuous insights.
#
# After extraction, the data undergoes a comprehensive cleaning and preprocessing pipeline, ensuring that the information — including product names, prices, ratings, discounts, and key technical specifications (RAM, Storage, Battery, Display, Processor, Camera) — is accurate and analysis-ready.
#
# The cleaned dataset is then used to train a machine learning model that predicts smartphone prices based on technical specifications, enabling data-driven insights into pricing patterns and feature impact.
#
# Finally, the results are visualized in Power BI, providing a complete end-to-end workflow — from live data collection to ML-based predictive analysis — demonstrating practical expertise in:
#
# - Web Scraping & Automation
# - Data Cleaning & Feature Engineering
# - Model Training & Evaluation (Price Prediction)
# - Interactive Visualization & Insights in Power BI

# %% [markdown]
# ---

# %% [markdown]
# ### Phase 1 - Web Scraping
#
#
# The first step in this project is to collect real-time smartphone data from Flipkart using Python web scraping tools such as Requests and BeautifulSoup. This phase focuses on extracting all essential product information to build a rich and reliable dataset for downstream analysis and machine learning.
#
# In this phase, we will scrape smartphone listings from **Flipkart** to capture essential details such as:
# - Brand & Model
# - Price & Discounts
# - Ratings
# - Key Specifications (RAM, ROM, Display, Battery, Processor, Camera, etc.)
#
# The scraped dataset will be stored in a structured format (CSV) and used in the next phase for transformation and analysis.

# %% [markdown]
# Importing Required Libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time, random

# %% [markdown]
# Let's defines the scraping function, iterates through all pages, extracts product details and stores the results into a CSV file.

# %%
# Base setup
BASE_URL = "https://www.flipkart.com/search?q=smartphones&page={}"
HEADERS = {"User-Agent": "Mozilla/5.0"}
TOTAL_PAGES = 390
OUTPUT_FILE = "flipkart_smartphones.csv"

# Store all products
all_products = []

def scrape_page(page_num):
    try:
        url = BASE_URL.format(page_num)
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"⚠️ Failed to fetch page {page_num}")
            return []
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return []
    
    soup = BeautifulSoup(response.text, "html.parser")
    data = []

    # Each product card
    product_cards = soup.find_all("div", {"class": "tUxRFH"})
    for card in product_cards:
        # Name
        name_tag = card.find("div", {"class": "KzDlHZ"})
        name = name_tag.text.strip() if name_tag else None

        # Price
        price_tag = card.find("div", {"class": "Nx9bqj _4b5DiR"})
        price = price_tag.text.strip().replace("₹", "").replace(",", "") if price_tag else None

        # Discount
        dis_tag = card.find("div", {"class": "UkUFwK"})
        discount = dis_tag.text.strip() if dis_tag else None

        # Rating
        rating_tag = card.find("div", {"class": "XQDdHH"})
        rating = rating_tag.text.strip() if rating_tag else None

        # Specs
        specs_container = card.find("div", {"class": "_6NESgJ"})
        if specs_container:
            specs_list = specs_container.find_all("li", {"class": "J+igdf"})
            specs = "; ".join([s.text.strip() for s in specs_list])
        else:
            specs = None

        if name:
            data.append({
                "Name": name,
                "Price": price,
                "Discount": discount,
                "Rating": rating,
                "Specs": specs
            })

    return data


# Main loop
for page in range(1, TOTAL_PAGES + 1):
    print(f"Scraping page {page}/{TOTAL_PAGES}...")
    products = scrape_page(page)
    all_products.extend(products)

    # Save progress every 50 pages
    if page % 50 == 0:
        pd.DataFrame(all_products).to_csv(OUTPUT_FILE, index=False)
        print(f"✅ Progress saved at page {page}")

    # Sleep to avoid blocking
    time.sleep(random.uniform(1, 3))

# Final save
df = pd.DataFrame(all_products)
df.to_csv(OUTPUT_FILE, index=False)
print(f"\n Done! Collected {len(df)} products into {OUTPUT_FILE}")
# Out:
# Scraping page 1/390...
# Scraping page 2/390...
# Scraping page 3/390...
# Scraping page 4/390...
# Scraping page 5/390...
# Scraping page 6/390...
# Scraping page 7/390...
# Scraping page 8/390...
# Scraping page 9/390...
# Scraping page 10/390...
# Scraping page 11/390...
# Scraping page 12/390...
# Scraping page 13/390...
# Scraping page 14/390...
# Scraping page 15/390...
# Scraping page 16/390...
# Scraping page 17/390...
# Scraping page 18/390...
# Scraping page 19/390...
# Scraping page 20/390...
# Scraping page 21/390...
# Scraping page 22/390...
# Scraping page 23/390...
# Scraping page 24/390...
# Scraping page 25/390...
# Scraping page 26/390...
# Scraping page 27/390...
# Scraping page 28/390...
# Scraping page 29/390...
# Scraping page 30/390...
# Scraping page 31/390...
# Scraping page 32/390...
# Scraping page 33/390...
# Scraping page 34/390...
# Scraping page 35/390...
# Scraping page 36/390...
# Scraping page 37/390...
# Scraping page 38/390...
# Scraping page 39/390...
# Scraping page 40/390...
# Scraping page 41/390...
# Scraping page 42/390...
# Scraping page 43/390...
# Scraping page 44/390...
# Scraping page 45/390...
# Scraping page 46/390...
# Scraping page 47/390...
# Scraping page 48/390...
# Scraping page 49/390...
# Scraping page 50/390...
# ✅ Progress saved at page 50
# Scraping page 51/390...
# Scraping page 52/390...
# Scraping page 53/390...
# Scraping page 54/390...
# Scraping page 55/390...
# Scraping page 56/390...
# Scraping page 57/390...
# Scraping page 58/390...
# Scraping page 59/390...
# Scraping page 60/390...
# Scraping page 61/390...
# Scraping page 62/390...
# Scraping page 63/390...
# Scraping page 64/390...
# Scraping page 65/390...
# Scraping page 66/390...
# Scraping page 67/390...
# Scraping page 68/390...
# Scraping page 69/390...
# Scraping page 70/390...
# Scraping page 71/390...
# Scraping page 72/390...
# Scraping page 73/390...
# Scraping page 74/390...
# Scraping page 75/390...
# Scraping page 76/390...
# Scraping page 77/390...
# Scraping page 78/390...
# Scraping page 79/390...
# Scraping page 80/390...
# Scraping page 81/390...
# Scraping page 82/390...
# Scraping page 83/390...
# Scraping page 84/390...
# Scraping page 85/390...
# Scraping page 86/390...
# Scraping page 87/390...
# Scraping page 88/390...
# Scraping page 89/390...
# Scraping page 90/390...
# Scraping page 91/390...
# Scraping page 92/390...
# Scraping page 93/390...
# Scraping page 94/390...
# Scraping page 95/390...
# Scraping page 96/390...
# Scraping page 97/390...
# Scraping page 98/390...
# Scraping page 99/390...
# Scraping page 100/390...
# ✅ Progress saved at page 100
# Scraping page 101/390...
# Scraping page 102/390...
# Scraping page 103/390...
# Scraping page 104/390...
# Scraping page 105/390...
# Scraping page 106/390...
# Scraping page 107/390...
# Scraping page 108/390...
# Scraping page 109/390...
# Scraping page 110/390...
# Scraping page 111/390...
# Scraping page 112/390...
# Scraping page 113/390...
# Scraping page 114/390...
# Scraping page 115/390...
# Scraping page 116/390...
# Scraping page 117/390...
# Scraping page 118/390...
# Scraping page 119/390...
# Scraping page 120/390...
# Scraping page 121/390...
# Scraping page 122/390...
# Scraping page 123/390...
# Scraping page 124/390...
# Scraping page 125/390...
# Scraping page 126/390...
# Scraping page 127/390...
# Scraping page 128/390...
# Scraping page 129/390...
# Scraping page 130/390...
# Scraping page 131/390...
# Scraping page 132/390...
# Scraping page 133/390...
# Scraping page 134/390...
# Scraping page 135/390...
# Scraping page 136/390...
# Scraping page 137/390...
# Scraping page 138/390...
# Scraping page 139/390...
# Scraping page 140/390...
# Scraping page 141/390...
# Scraping page 142/390...
# Scraping page 143/390...
# Scraping page 144/390...
# Scraping page 145/390...
# Scraping page 146/390...
# Scraping page 147/390...
# Scraping page 148/390...
# Scraping page 149/390...
# Scraping page 150/390...
# ✅ Progress saved at page 150
# Scraping page 151/390...
# Scraping page 152/390...
# Scraping page 153/390...
# Scraping page 154/390...
# Scraping page 155/390...
# Scraping page 156/390...
# Scraping page 157/390...
# Scraping page 158/390...
# Scraping page 159/390...
# Scraping page 160/390...
# Scraping page 161/390...
# Scraping page 162/390...
# Scraping page 163/390...
# Scraping page 164/390...
# Scraping page 165/390...
# Scraping page 166/390...
# Scraping page 167/390...
# Scraping page 168/390...
# Scraping page 169/390...
# Scraping page 170/390...
# Scraping page 171/390...
# Scraping page 172/390...
# Scraping page 173/390...
# Scraping page 174/390...
# Scraping page 175/390...
# Scraping page 176/390...
# Scraping page 177/390...
# Scraping page 178/390...
# Scraping page 179/390...
# Scraping page 180/390...
# Scraping page 181/390...
# Scraping page 182/390...
# Scraping page 183/390...
# Scraping page 184/390...
# Scraping page 185/390...
# Scraping page 186/390...
# Scraping page 187/390...
# Scraping page 188/390...
# Scraping page 189/390...
# Scraping page 190/390...
# Scraping page 191/390...
# Scraping page 192/390...
# Scraping page 193/390...
# Scraping page 194/390...
# Scraping page 195/390...
# Scraping page 196/390...
# Scraping page 197/390...
# Scraping page 198/390...
# Scraping page 199/390...
# Scraping page 200/390...
# ✅ Progress saved at page 200
# Scraping page 201/390...
# Scraping page 202/390...
# Scraping page 203/390...
# Scraping page 204/390...
# Scraping page 205/390...
# Scraping page 206/390...
# Scraping page 207/390...
# Scraping page 208/390...
# Scraping page 209/390...
# Scraping page 210/390...
# Scraping page 211/390...
# Scraping page 212/390...
# Scraping page 213/390...
# Scraping page 214/390...
# Scraping page 215/390...
# Scraping page 216/390...
# Scraping page 217/390...
# Scraping page 218/390...
# Scraping page 219/390...
# Scraping page 220/390...
# Scraping page 221/390...
# Scraping page 222/390...
# Scraping page 223/390...
# Scraping page 224/390...
# Scraping page 225/390...
# Scraping page 226/390...
# Scraping page 227/390...
# Scraping page 228/390...
# Scraping page 229/390...
# Scraping page 230/390...
# Scraping page 231/390...
# Scraping page 232/390...
# Scraping page 233/390...
# Scraping page 234/390...
# Scraping page 235/390...
# Scraping page 236/390...
# Scraping page 237/390...
# Scraping page 238/390...
# Scraping page 239/390...
# Scraping page 240/390...
# Scraping page 241/390...
# Scraping page 242/390...
# Scraping page 243/390...
# Scraping page 244/390...
# Scraping page 245/390...
# Scraping page 246/390...
# Scraping page 247/390...
# Scraping page 248/390...
# Scraping page 249/390...
# Scraping page 250/390...
# ✅ Progress saved at page 250
# Scraping page 251/390...
# Scraping page 252/390...
# Scraping page 253/390...
# Scraping page 254/390...
# Scraping page 255/390...
# Scraping page 256/390...
# Scraping page 257/390...
# Scraping page 258/390...
# Scraping page 259/390...
# Scraping page 260/390...
# Scraping page 261/390...
# Scraping page 262/390...
# Scraping page 263/390...
# Scraping page 264/390...
# Scraping page 265/390...
# Scraping page 266/390...
# Scraping page 267/390...
# Scraping page 268/390...
# Scraping page 269/390...
# Scraping page 270/390...
# Scraping page 271/390...
# Scraping page 272/390...
# Scraping page 273/390...
# Scraping page 274/390...
# Scraping page 275/390...
# Scraping page 276/390...
# Scraping page 277/390...
# Scraping page 278/390...
# Scraping page 279/390...
# Scraping page 280/390...
# Scraping page 281/390...
# Scraping page 282/390...
# Scraping page 283/390...
# Scraping page 284/390...
# Scraping page 285/390...
# Scraping page 286/390...
# Scraping page 287/390...
# Scraping page 288/390...
# Scraping page 289/390...
# Scraping page 290/390...
# Scraping page 291/390...
# Scraping page 292/390...
# Scraping page 293/390...
# Scraping page 294/390...
# Scraping page 295/390...
# Scraping page 296/390...
# Scraping page 297/390...
# Scraping page 298/390...
# Scraping page 299/390...
# Scraping page 300/390...
# ✅ Progress saved at page 300
# Scraping page 301/390...
# Scraping page 302/390...
# Scraping page 303/390...
# Scraping page 304/390...
# Scraping page 305/390...
# Scraping page 306/390...
# Scraping page 307/390...
# Scraping page 308/390...
# Scraping page 309/390...
# Scraping page 310/390...
# Scraping page 311/390...
# Scraping page 312/390...
# Scraping page 313/390...
# Scraping page 314/390...
# Scraping page 315/390...
# Scraping page 316/390...
# Scraping page 317/390...
# Scraping page 318/390...
# Scraping page 319/390...
# Scraping page 320/390...
# Scraping page 321/390...
# Scraping page 322/390...
# Scraping page 323/390...
# Scraping page 324/390...
# Scraping page 325/390...
# Scraping page 326/390...
# Scraping page 327/390...
# Scraping page 328/390...
# Scraping page 329/390...
# Scraping page 330/390...
# Scraping page 331/390...
# Scraping page 332/390...
# Scraping page 333/390...
# Scraping page 334/390...
# Scraping page 335/390...
# Scraping page 336/390...
# Scraping page 337/390...
# Scraping page 338/390...
# Scraping page 339/390...
# Scraping page 340/390...
# Scraping page 341/390...
# Scraping page 342/390...
# Scraping page 343/390...
# Scraping page 344/390...
# Scraping page 345/390...
# Scraping page 346/390...
# Scraping page 347/390...
# Scraping page 348/390...
# Scraping page 349/390...
# Scraping page 350/390...
# ✅ Progress saved at page 350
# Scraping page 351/390...
# Scraping page 352/390...
# Scraping page 353/390...
# Scraping page 354/390...
# Scraping page 355/390...
# Scraping page 356/390...
# Scraping page 357/390...
# Scraping page 358/390...
# Scraping page 359/390...
# Scraping page 360/390...
# Scraping page 361/390...
# Scraping page 362/390...
# Scraping page 363/390...
# Scraping page 364/390...
# Scraping page 365/390...
# Scraping page 366/390...
# Scraping page 367/390...
# Scraping page 368/390...
# Scraping page 369/390...
# Scraping page 370/390...
# Scraping page 371/390...
# Scraping page 372/390...
# Scraping page 373/390...
# Scraping page 374/390...
# Scraping page 375/390...
# Scraping page 376/390...
# Scraping page 377/390...
# Scraping page 378/390...
# Scraping page 379/390...
# Scraping page 380/390...
# Scraping page 381/390...
# Scraping page 382/390...
# Scraping page 383/390...
# Scraping page 384/390...
# Scraping page 385/390...
# Scraping page 386/390...
# Scraping page 387/390...
# Scraping page 388/390...
# Scraping page 389/390...
# Scraping page 390/390...
#
#  Done! Collected 984 products into flipkart_smartphones.csv

# %% [markdown]
# ---

# %% [markdown]
# ### Phase 2 - Data Preparation & Transformation
#
# With the web scraping phase complete, we have successfully gathered raw smartphone listings from Flipkart and saved them as flipkart_smartphones.csv.
# This dataset now serves as the foundation for both exploratory analysis and machine learning model training.
#
# In the Data Preparation & Transformation phase, we will -
#
# - Evaluate and enhance overall data quality
# - Handle missing, inconsistent, and duplicate records
# - Standardize technical specifications (RAM, ROM, Battery, Display, Processor, Camera) into numeric formats
# - Engineer relevant features for model input
# - Prepare a clean and structured dataset suitable for Exploratory Data Analysis (EDA) and Price Prediction Modeling
#
# *This phase ensures that the data is accurate, consistent, and machine-learning-ready — forming the backbone of the predictive analytics workflow.*

# %% [markdown]
# ---
# ---
